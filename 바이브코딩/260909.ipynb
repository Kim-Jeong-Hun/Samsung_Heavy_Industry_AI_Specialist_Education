# %%
# 키 등록
# 환경변수 편집

# pip install anthropic

# %%
import os
import anthropic

client = anthropic.Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"])

message = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=1024,
    messages=[{"role": "user", "content": "너는 누구야?"}],
)

print(message.content[0].text)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 6
#       2 import anthropic
#       3
#       4 client = anthropic.Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"])
#       5
# ----> 6 message = client.messages.create(
#       7     model="claude-sonnet-5",
#       8     max_tokens=1024,
#       9     messages=[{"role": "user", "content": "너는 누구야?"}],
#
# File ~\Documents\GitHub\Samsung_Heavy_Industry_AI_Specialist_Education\바이브코딩\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~\Documents\GitHub\Samsung_Heavy_Industry_AI_Specialist_Education\바이브코딩\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:980, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     965     warnings.warn(
#     966         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     967         UserWarning,
#     968         stacklevel=3,
#     969     )
#     971 extra_headers = {
#     972     **strip_not_given(
#     973         {
#    (...)    978     **(extra_headers or {}),
#     979 }
# --> 980 return self._post(
#     981     "/v1/messages",
#     982     body=maybe_transform(
#     983         {
#     984             "max_tokens": max_tokens,
#     985             "messages": messages,
#     986             "model": model,
#     987             "cache_control": cache_control,
#     988             "container": container,
#     989             "inference_geo": inference_geo,
#     990             "metadata": metadata,
#     991             "output_config": output_config,
#     992             "service_tier": service_tier,
#     993             "stop_sequences": stop_sequences,
#     994             "stream": stream,
#     995             "system": system,
#     996             "thinking": thinking,
#     997             "tool_choice": tool_choice,
#     998             "tools": tools,
#     999         },
#    1000         message_create_params.MessageCreateParamsStreaming
#    1001         if stream
#    1002         else message_create_params.MessageCreateParamsNonStreaming,
#    1003     ),
#    1004     options=make_request_options(
#    1005         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1006     ),
#    1007     cast_to=Message,
#    1008     stream=stream or False,
#    1009     stream_cls=Stream[RawMessageStreamEvent],
#    1010 )
#
# File ~\Documents\GitHub\Samsung_Heavy_Industry_AI_Specialist_Education\바이브코딩\.venv\Lib\site-packages\anthropic\_base_client.py:1507, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1503     raise TypeError("Passing both `files` and `content` is not supported")
#    1504 opts = FinalRequestOptions.construct(
#    1505     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1506 )
# -> 1507 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\GitHub\Samsung_Heavy_Industry_AI_Specialist_Education\바이브코딩\.venv\Lib\site-packages\anthropic\_base_client.py:1191, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1188     if not response.is_closed:
#    1189         response.read()
# -> 1191     raise self._make_status_error_from_response(response) from None
#    1193 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011Ces3NJzPX1xuQvVSpJhzp'}
